# %%
from importlib.metadata import version
import pandas as pd
import numpy as np
import sklearn
import hdbscan
import lifetimes
import streamlit

packages = ['pandas', 'numpy', 'scikit-learn', 'scipy', 'matplotlib',
            'seaborn', 'plotly', 'hdbscan', 'lifetimes', 'streamlit',
            'pyarrow', 'openpyxl', 'joblib', 'jupyter', 'ipykernel']

for pkg in packages:
    try:
        print(f"{pkg}: {version(pkg)}")
    except Exception as e:
        print(f"{pkg}: NOT FOUND ({e})")

# Quick data load test
df = pd.read_excel("../data/raw/online_retail_II.xlsx", sheet_name="Year 2009-2010")
print(f"\nData loaded: {df.shape[0]:,} rows, {df.shape[1]} columns")
print(df.head())
# Out:
# pandas: 2.1.4
# numpy: 1.26.4
# scikit-learn: 1.7.2
# scipy: 1.15.3
# matplotlib: 3.8.2
# seaborn: 0.13.1
# plotly: 5.18.0
# hdbscan: 0.8.43
# lifetimes: 0.11.3
# streamlit: 1.29.0
# pyarrow: 24.0.0
# openpyxl: 3.1.2
# joblib: 1.5.3
# jupyter: 1.0.0
# ipykernel: 6.28.0
#
# Data loaded: 525,461 rows, 8 columns
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# ...
